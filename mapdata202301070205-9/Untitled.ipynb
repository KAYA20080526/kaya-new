# %%
! pip install geopandas
# !pip install pyshp
# Out:
# Requirement already satisfied: geopandas in /opt/anaconda3/lib/python3.11/site-packages (0.14.3)
# Requirement already satisfied: fiona>=1.8.21 in /opt/anaconda3/lib/python3.11/site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from geopandas) (2.1.4)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: attrs>=19.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: pyshp in /opt/anaconda3/lib/python3.11/site-packages (2.3.1)

# %%
import geopandas as gpd
# Read shp data of Taiwan county 
# 縣市界
Rice_data = gpd.read_file("/Users/ho-yehcheng/Documents/GitHub/mapdata202301070205-9/COA_OpenData-44.csv")
# Display data 顯示前5筆

print(Rice_data)
# Out:
#      yield COUNTYNAME geometry
# 0        0        基隆市     None
# 1        0        澎湖縣     None
# 2        0        高雄縣     None
# 3        0        台南縣     None
# 4     6894        臺北市     None
# 5    12055        新北市     None
# 6    14940        新竹市     None
# 7    15524        宜蘭縣     None
# 8    22061        桃園市     None
# 9    25631        新竹市     None
# 10   30751        臺東縣     None
# 11   33128        南投縣     None
# 12   36916        高雄市     None
# 13   41515        臺中市     None
# 14   42811        臺南市     None
# 15   44917        花蓮縣     None
# 16   45159        苗栗縣     None
# 17   47621        屏東縣     None
# 18   49708        雲林縣     None
# 19   69997        彰化縣     None
# 20  102583        嘉義市     None

# %%
# !pip install --upgrade pip !pip cache clear !pip install pyshp

# !pip install numpy !pip install geopandas

# !pip install pyshp
# Out:
# ERROR: Invalid requirement: '!pip'
# ERROR: Invalid requirement: '!pip'
# Requirement already satisfied: pyshp in /opt/anaconda3/lib/python3.11/site-packages (2.3.1)

# %%
import geopandas as gpd
County_data = gpd.read_file("/Users/ho-yehcheng/Documents/GitHub/mapdata202301070205-9/mapdata202301070205-11/COUNTY_MOI_1090820.shp")
County_data
# Out:
#    COUNTYID COUNTYCODE COUNTYNAME          COUNTYENG  \
# 0         Z      09007        連江縣  Lienchiang County
# 1         G      10002        宜蘭縣       Yilan County
# 2         N      10007        彰化縣    Changhua County
# 3         M      10008        南投縣      Nantou County
# 4         P      10009        雲林縣      Yunlin County
# 5         C      10017        基隆市       Keelung City
# 6         A      63000        臺北市        Taipei City
# 7         F      65000        新北市    New Taipei City
# 8         B      66000        臺中市      Taichung City
# 9         D      67000        臺南市        Tainan City
# 10        H      68000        桃園市       Taoyuan City
# 11        K      10005        苗栗縣      Miaoli County
# 12        I      10020        嘉義市        Chiayi City
# 13        Q      10010        嘉義縣      Chiayi County
# 14        W      09020        金門縣      Kinmen County
# 15        E      64000        高雄市     Kaohsiung City
# 16        V      10014        臺東縣     Taitung County
# 17        U      10015        花蓮縣     Hualien County
# 18        X      10016        澎湖縣      Penghu County
# 19        O      10018        新竹市       Hsinchu City
# 20        J      10004        新竹縣     Hsinchu County
# 21        T      10013        屏東縣    Pingtung County
#
#                                              geometry
# 0   MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1   MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2   POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3   POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4   MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 5   MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...
# 6   POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 7   POLYGON ((121.53752 25.30003, 121.53768 25.300...
# 8   POLYGON ((121.32834 24.43304, 121.32845 24.432...
# 9   POLYGON ((120.44025 23.41308, 120.44040 23.413...
# 10  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 11  POLYGON ((121.00820 24.64432, 121.00828 24.644...
# 12  POLYGON ((120.44758 23.51819, 120.44767 23.518...
# 13  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...
# 14  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...
# 15  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...
# 16  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 17  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 18  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...
# 19  POLYGON ((120.92532 24.85478, 120.92545 24.854...
# 20  POLYGON ((121.03813 24.94638, 121.03822 24.946...
# 21  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...

# %%
## plot data
Sample_data = County_data.loc[:, ['COUNTYNAME', 'geometry']]
Sample_data.plot()
# Out:
# <Axes: >

# %%
County_data[['COUNTYNAME', 'geometry']]
# Out:
#    COUNTYNAME                                           geometry
# 0         連江縣  MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1         宜蘭縣  MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2         彰化縣  POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3         南投縣  POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4         雲林縣  MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 5         基隆市  MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...
# 6         臺北市  POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 7         新北市  POLYGON ((121.53752 25.30003, 121.53768 25.300...
# 8         臺中市  POLYGON ((121.32834 24.43304, 121.32845 24.432...
# 9         臺南市  POLYGON ((120.44025 23.41308, 120.44040 23.413...
# 10        桃園市  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 11        苗栗縣  POLYGON ((121.00820 24.64432, 121.00828 24.644...
# 12        嘉義市  POLYGON ((120.44758 23.51819, 120.44767 23.518...
# 13        嘉義縣  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...
# 14        金門縣  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...
# 15        高雄市  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...
# 16        臺東縣  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 17        花蓮縣  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 18        澎湖縣  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...
# 19        新竹市  POLYGON ((120.92532 24.85478, 120.92545 24.854...
# 20        新竹縣  POLYGON ((121.03813 24.94638, 121.03822 24.946...
# 21        屏東縣  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...

# %%
County_data = County_data. rename(columns={ 'geometry': 'county_geometry'})

# 合併'Rice_data'和'County_data'避免和後面要合併的'Rice_data'中的'geometry'列重名
merged_data = Rice_data.merge(County_data[ ['COUNTYNAME', 'county_geometry']], on='COUNTYNAME', how='left' )

# # 將合併後的'county_geometry’列的值插入'Town_data'的'geometry'列，這樣 merged_data 就有了'geometry'列。
merged_data ['geometry'] = County_data['county_geometry']

# # 顯示合併後的 GeoDataFrame
merged_data
# Out:
#      yield COUNTYNAME                                           geometry  \
# 0        0        基隆市  MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1        0        澎湖縣  MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2        0        高雄縣  POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3        0        台南縣  POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4     6894        臺北市  MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 5    12055        新北市  MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...
# 6    14940        新竹市  POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 7    15524        宜蘭縣  POLYGON ((121.53752 25.30003, 121.53768 25.300...
# 8    22061        桃園市  POLYGON ((121.32834 24.43304, 121.32845 24.432...
# 9    25631        新竹市  POLYGON ((120.44025 23.41308, 120.44040 23.413...
# 10   30751        臺東縣  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 11   33128        南投縣  POLYGON ((121.00820 24.64432, 121.00828 24.644...
# 12   36916        高雄市  POLYGON ((120.44758 23.51819, 120.44767 23.518...
# 13   41515        臺中市  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...
# 14   42811        臺南市  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...
# 15   44917        花蓮縣  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...
# 16   45159        苗栗縣  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 17   47621        屏東縣  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 18   49708        雲林縣  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...
# 19   69997        彰化縣  POLYGON ((120.92532 24.85478, 120.92545 24.854...
# 20  102583        嘉義市  POLYGON ((121.03813 24.94638, 121.03822 24.946...
#
#    county_geometry
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None
# 10            None
# 11            None
# 12            None
# 13            None
# 14            None
# 15            None
# 16            None
# 17            None
# 18            None
# 19            None
# 20            None

# %%
import numpy as np
for i in merged_data['yield'].index:
    merged_data.loc[i, 'yield'] = np.int64(merged_data.loc[i, 'yield'])
type(int(merged_data['yield'][20]))
# Out:
# int

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 將資料轉換為 GeoDataFrame，並將 'geometry' 列重新命名為 'geom'

gdf = gpd.GeoDataFrame(merged_data, geometry='geometry')
gdf.rename_geometry('geom', inplace=True)
# 畫出地圖
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
gdf.plot(column='yield', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# 添加標題
plt.title('Rice Population', fontdict={'fontsize': '15', 'fontweight' : '6'})

# 顯示圖表
plt.show()
